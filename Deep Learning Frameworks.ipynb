# %%
"""
Q1.What is TensorFlow 2.0, and how is it different from TensorFlow 1.x?

TensorFlow 2.0 is an open-source machine learning framework that emphasizes ease of use, flexibility, and performance. Key differences from TensorFlow 1.x include:
Eager Execution: Enabled by default for immediate operation evaluation.
Keras Integration: Keras is the high-level API for building models.
Simplified APIs: Streamlined and reduced redundancy in APIs.
Improved TensorFlow Hub Support: Enhanced support for pre-trained models.
"""
# Out:
# '\nWhat is TensorFlow 2.0, and how is it different from TensorFlow 1.x?\n\nTensorFlow 2.0 is an open-source machine learning framework that emphasizes ease of use, flexibility, and performance. Key differences from TensorFlow 1.x include:\nEager Execution: Enabled by default for immediate operation evaluation.\nKeras Integration: Keras is the high-level API for building models.\nSimplified APIs: Streamlined and reduced redundancy in APIs.\nImproved TensorFlow Hub Support: Enhanced support for pre-trained models.\n'

# %%
#Q2.How do you install TensorFlow 2.0?

"""
Use pip to install TensorFlow 2.0:
"""
# !pip install tensorflow==2.0.0

# %%
#Q3.What is the primary function of the tf.function in TensorFlow 2.0?
"""
The tf.function decorator converts a Python function into a TensorFlow graph, optimizing performance and enabling better deployment.
What is the purpose of the Model class in TensorFlow 2.0?

The Model class serves as a base for building, training, and evaluating neural network models, allowing for custom architectures.
"""
# Out:
# '\nThe tf.function decorator converts a Python function into a TensorFlow graph, optimizing performance and enabling better deployment.\nWhat is the purpose of the Model class in TensorFlow 2.0?\n\nThe Model class serves as a base for building, training, and evaluating neural network models, allowing for custom architectures.\n'

# %%
#Q5.How do you create a neural network using TensorFlow 2.0?
     import tensorflow as tf
     from tensorflow.keras import layers, models
     model = models.Sequential([
         layers.Dense(64, activation='relu', input_shape=(input_dim,)),
         layers.Dense(64, activation='relu'),
         layers.Dense(num_classes, activation='softmax')
     ])

# %%
#Q6.What is the importance of Tensor Space in TensorFlow?
"""
Tensor space refers to the multi-dimensional array structure (tensors) used in TensorFlow,
which is crucial for efficient computation and data manipulation.
 """

# %%
#Q7.How can TensorBoard be integrated with TensorFlow 2.0?
     import tensorflow as tf
     log_dir = "logs/"
     summary_writer = tf.summary.create_file_writer(log_dir)
     with summary_writer.as_default():
         tf.summary.scalar('loss', loss_value, step=epoch)

# %%
#Q8.What is the purpose of TensorFlow Playground?
"""
TensorFlow Playground is an interactive web application for experimenting with neural networks visually,
allowing users to adjust parameters and visualize training.
"""
#Q9.What is Netron, and how is it useful for deep learning models?
"""
Netron is a viewer for neural network models that supports various formats,
allowing users to visualize model architecture and inspect layers.
"""

#Q10.What is the difference between TensorFlow and PyTorch?

"""
Execution Model: TensorFlow (1.x) uses static graphs; TensorFlow 2.0 and PyTorch use dynamic graphs.
Ease of Use: PyTorch is often considered more intuitive and easier to debug.
Community and Ecosystem: TensorFlow has a larger ecosystem, while PyTorch is popular in research.
"""

#Q13.What is the significance of tensors in PyTorch?
"""
Tensors are the core data structure in PyTorch, enabling efficient computation and representing inputs, outputs, and model parameters.
"""
#Q14.What is the difference between torch.Tensor and torch.cuda.Tensor in PyTorch?

"""
torch.Tensor is a CPU tensor, while torch.cuda.Tensor is a GPU tensor, allowing for accelerated computation.
"""
#Q15.What is the purpose of the torch.optim module in PyTorch?
"""
The torch.optim module provides optimization algorithms (like SGD, Adam) to update model parameters during training.
"""
#Q16.What are some common activation functions used in neural networks?
"""
Common activation functions include:
ReLU (Rectified Linear Unit)
Sigmoid
Tanh
Softmax
"""
#Q17.What is the difference between torch.nn.Module and torch.nn.Sequential in PyTorch?
"""
torch.nn.Module is a base class for creating custom models, while torch.nn.Sequential is a container for stacking layers in a linear fashion.
"""
#Q18.How can you monitor training progress in TensorFlow 2.0?
"""
You can monitor training progress using TensorBoard, logging metrics with tf.summary, or using callbacks like tf.keras.callbacks.EarlyStopping.
"""
#Q19.How does the Keras API fit into TensorFlow 2.0?
"""
Keras is integrated as the high-level API in TensorFlow 2.0, simplifying model building, training, and evaluation.

"""
#Q20.What is an example of a deep learning project that can be implemented using TensorFlow 2.0?

"""
An example project could be image classification using convolutional neural networks (CNNs) on datasets like CIFAR-10 or MNIST.
"""
#Q21What is the main advantage of using pre-trained models in TensorFlow and PyTorch?
"""
The main advantage is transfer learning, where pre-trained models can be fine-tuned on new tasks,
saving time and computational resources while improving performance.
"""

#Q11.How do you install PyTorch?
 """
 pip install torch torchvision torchaudio
 """

 #Q12.What is the basic structure of a PyTorch neural network?

      import torch
      import torch.nn as nn
      class SimpleNN(nn.Module):
          def __init__(self):
              super(SimpleNN, self).__init__()
              self.fc1 = nn.Linear(input_dim, 64)
              self.fc2 = nn.Linear(64, num_classes)
          def forward(self, x):
              x = torch.relu(self.fc1(x))
              x = self.fc2(x)
              return x

# %% [markdown]
# Practicle

# %%
#Q1.How do you install and verify that TensorFlow 2.0 was installed successfully?
"installation"
# !pip install tensorflow==2.0.0

"verification"
import tensorflow as tf
print(tf.__version__)  # Should print 2.0.0


#Q2.How can you define a simple function in TensorFlow 2.0 to perform addition?

     @tf.function
     def add(a, b):
         return a + b

     result = add(tf.constant(2), tf.constant(3))
     print(result.numpy())  # Output: 5

#Q3.How can you create a simple neural network in TensorFlow 2.0 with one hidden layer?
     import tensorflow as tf
     from tensorflow.keras import layers, models

     model = models.Sequential([
         layers.Dense(10, activation='relu', input_shape=(input_dim,)),  # Hidden layer
         layers.Dense(1, activation='sigmoid')  # Output layer
     ])

     model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])


#Q4.How can you visualize the training progress using TensorFlow and Matplotlib?

     import tensorflow as tf
     from tensorflow.keras import layers, models

     model = models.Sequential([
         layers.Dense(10, activation='relu', input_shape=(input_dim,)),  # Hidden layer
         layers.Dense(1, activation='sigmoid')  # Output layer
     ])

     model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])


#Q5.How do you install PyTorch and verify the PyTorch installation?

# !pip install torch torchvision torchaudio

#Q6.How do you create a simple neural network in PyTorch?

     import torch
     import torch.nn as nn

     class SimpleNN(nn.Module):
         def __init__(self):
             super(SimpleNN, self).__init__()
             self.fc1 = nn.Linear(input_dim, 10)  # Hidden layer
             self.fc2 = nn.Linear(10, 1)           # Output layer

         def forward(self, x):
             x = torch.relu(self.fc1(x))
             x = torch.sigmoid(self.fc2(x))
             return x

     model = SimpleNN()



#Q7.How do you define a loss function and optimizer in PyTorch?

     criterion = nn.BCELoss()  # Binary Cross Entropy Loss
     optimizer = torch.optim.Adam(model.parameters(), lr=0.001)


#Q8.How do you implement a custom loss function in PyTorch?

     class CustomLoss(nn.Module):
         def __init__(self):
             super(CustomLoss, self).__init__()

         def forward(self, output, target):
             return torch.mean((output - target) ** 2)  # Mean Squared Error

     custom_loss = CustomLoss()

#Q9.How do you save and load a TensorFlow model?

Saving a model:
     class CustomLoss(nn.Module):
         def __init__(self):
             super(CustomLoss, self).__init__()

         def forward(self, output, target):
             return torch.mean((output - target) ** 2)  # Mean Squared Error

     custom_loss = CustomLoss()

Loading a model:

     loaded_model = tf.keras.models.load_model('my_model.h5')
